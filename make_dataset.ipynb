# %%
import glob
import pytesseract
from PIL import Image
import cv2
import matplotlib.pyplot as plt
import random
import numpy as np
import os
import shutil

# %%
folders = os.listdir('/media/hadis/E41CDB061CDAD322/Data')
folders
# Out:
# ['1#Progress Note (OPD)',
#  '10#Pre Anesthesia Evaluation',
#  '100#پزشکی قانونی',
#  '101#General Surgery pre-op Nurs note',
#  '102#چک لیست تحویل و انتقال بیمار بین بخش ها',
#  '104#ثبت عملیات احیای نوزادان',
#  '105#رضایت برای بستن لوله رحم',
#  '106#Adult Health Primary assistment Sheet',
#  '107#فرم کنترل مادر پرخطر',
#  '108#کارت مراقبت دوران بارداری',
#  '109#گزارش زخم بستر',
#  '11#Anesthesia  Record',
#  '110#فرم آموزش بیمار در بدو ورود و حین بستریtekrari-',
#  '111#Toxemia',
#  '113#Surgico-medical notes sheet',
#  '114#pre-operation lab evalution',
#  '115#tee with contrast report',
#  '116#induction record',
#  '117#فرم عدم رضایت جهت انجام آنژیوپلاستی',
#  '118#Cataract surgery Ancillary Diagnostic form',
#  '119#چک لیست حاکمیت بالینی',
#  '12#Pre-Operation Care Sheet',
#  '120#پایش تغییر وضعیت بیمار',
#  '121#mamography',
#  '122#intake output sheet',
#  '123#Department of radiology',
#  '124#Elctrophysiology lab',
#  '125#ventilator',
# ...

# %%
len(folders)
# Out:
# 141

# %%
f  = os.listdir('Data')
len(f)
# Out:
# 141

# %%
for folder in folders[124:]:
    print(folder,'\n')
    file_path = glob.glob('/media/hadis/E41CDB061CDAD322/Data/'+folder+'/*.tif')
    os.mkdir(folder)
    pic = random.sample(file_path,k=20)
    for i in pic:
        shutil.copy2(i,folder)
        print('moved')
# Out:
# 81#Angiography Nurse note
#
# moved
# moved
# moved
# moved
# moved
# moved
# moved
# moved
# moved
# moved
# moved
# moved
# moved
# moved
# moved
# moved
# moved
# moved
# moved
# moved
# 82#Angio Admission note
#
# moved
# moved
# moved
# moved
# moved
# moved
# moved
# moved
# moved
# moved
# moved
# moved
# moved
# moved
# moved
# moved
# moved
# moved
# moved
# moved
# 83#چک لیست کت لب ایمن
#
# moved
# moved
# moved
# moved
# moved
# moved
# moved
# moved
# moved
# moved
# moved
# moved
# moved
# moved
# moved
# moved
# moved
# moved
# moved
# moved
# 85#perfusion record
#
# moved
# moved
# moved
# moved
# moved
# moved
# moved
# moved
# moved
# moved
# moved
# moved
# moved
# moved
# moved
# moved
# moved
# moved
# moved
# moved
# 86#Primary Assessment sheet
#
# moved
# moved
# moved
# moved
# moved
# moved
# moved
# moved
# moved
# moved
# moved
# moved
# moved
# moved
# moved
# moved
# moved
# moved
# moved
# moved
# 87#امتیاز ارزیابی خطر بروز زخم فشاری
#
# moved
# moved
# ...

# %%
path = "/media/hadis/E41CDB061CDAD322/Data/73#فرم اورژانس 115"

# %%
imageFiles = glob.glob( path + '/*.tif')

# %%
imageFiles
# Out:
# ['/media/hadis/E41CDB061CDAD322/Data/73#فرم اورژانس 115/165179_797061bf-a6d6-4e4e-9ded-01dcd789cef6_0.tif',
#  '/media/hadis/E41CDB061CDAD322/Data/73#فرم اورژانس 115/165333_7df17dd0-d7cd-4b4b-b00c-7775ef4f468a_0.tif',
#  '/media/hadis/E41CDB061CDAD322/Data/73#فرم اورژانس 115/165404_0534ed9e-c70f-4e7c-8e51-9a26db24209e_0.tif',
#  '/media/hadis/E41CDB061CDAD322/Data/73#فرم اورژانس 115/165404_ff8af9db-3c51-4bd4-8c84-02aaeb9fa53d_0.tif',
#  '/media/hadis/E41CDB061CDAD322/Data/73#فرم اورژانس 115/165505_63e0bba3-4b2c-4fc1-a06d-dafbc9145fba_0.tif',
#  '/media/hadis/E41CDB061CDAD322/Data/73#فرم اورژانس 115/165505_a6c4b8db-5a94-4fea-b8ad-7ea66bbfde90_0.tif',
#  '/media/hadis/E41CDB061CDAD322/Data/73#فرم اورژانس 115/165551_3616564a-0bcf-4e64-9e49-47ddeed76ab0_0.tif',
#  '/media/hadis/E41CDB061CDAD322/Data/73#فرم اورژانس 115/165600_8c72982e-238b-4546-bdec-9a99ab65052a_0.tif',
#  '/media/hadis/E41CDB061CDAD322/Data/73#فرم اورژانس 115/165600_d09a2e2a-0b72-4181-bf40-0abc930a2d8b_0.tif',
# ...

# %%
os.mkdir('2#Addmission & Discharge')
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# /tmp/ipykernel_4389/2985386618.py in <module>
# ----> 1 os.mkdir('2#Addmission & Discharge')
#
# FileExistsError: [Errno 17] File exists: '2#Addmission & Discharge'

# %%
pic = random.sample(imageFiles,k=20)
pic
# Out:
# ['/media/hadis/E41CDB061CDAD322/Data/73#فرم اورژانس 115/172322_40e42879-035a-4dd7-836c-d66f0679075a_1.tif',
#  '/media/hadis/E41CDB061CDAD322/Data/73#فرم اورژانس 115/96007766_537b14e8-97df-489c-ad8b-95ad398c4a8a_0.tif',
#  '/media/hadis/E41CDB061CDAD322/Data/73#فرم اورژانس 115/185982_5cc6ee31-290f-4c3c-83de-0ef823a3961b_0.tif',
#  '/media/hadis/E41CDB061CDAD322/Data/73#فرم اورژانس 115/183538_eeef0861-1a2b-4562-8ff8-70b64a05a202_1.tif',
#  '/media/hadis/E41CDB061CDAD322/Data/73#فرم اورژانس 115/168820_3d6b7aaf-efad-4806-900c-f4ae5ac1128f_1.tif',
#  '/media/hadis/E41CDB061CDAD322/Data/73#فرم اورژانس 115/169113_9702677c-c002-44c9-b5c1-9a5bb168265d_0.tif',
#  '/media/hadis/E41CDB061CDAD322/Data/73#فرم اورژانس 115/181132_b5549fbb-ff65-4719-b33c-34f174143d01_1.tif',
#  '/media/hadis/E41CDB061CDAD322/Data/73#فرم اورژانس 115/168931_cd5c23ad-b9fe-4e2a-a416-c373c8977048_0.tif',
#  '/media/hadis/E41CDB061CDAD322/Data/73#فرم اورژانس 115/177184_5fba08ae-70c4-4b69-b0e5-6a03e8bef851_1.tif',
# ...

# %%
for i in pic:
    shutil.copy2(i,'73#فرم اورژانس 115')
    print('moved')
# Out:
# moved
# moved
# moved
# moved
# moved
# moved
# moved
# moved
# moved
# moved
# moved
# moved
# moved
# moved
# moved
# moved
# moved
# moved
# moved
# moved

# %%
# Out:
# True
