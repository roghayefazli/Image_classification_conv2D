# %%
import glob
import pytesseract
from PIL import Image
import cv2
import matplotlib.pyplot as plt
import random
import numpy as np
import os

# %%
path = "/media/hadis/E41CDB061CDAD322/Data/183#گزارش زخم فشاری"

# %%
imageFiles = glob.glob( path + '/*.tif')

# %%
imageFiles
# Out:
# ['/media/hadis/E41CDB061CDAD322/Data/183#گزارش زخم فشاری/40268671_56272cf7-4667-413b-b271-5e3c07e095a9_0.tif',
#  '/media/hadis/E41CDB061CDAD322/Data/183#گزارش زخم فشاری/40268671_7f9554ce-3f01-4cd0-91e2-ed6753936ba3_0.tif',
#  '/media/hadis/E41CDB061CDAD322/Data/183#گزارش زخم فشاری/40268671_81e9b6eb-9864-4902-ad35-8380d564e86e_1.tif',
#  '/media/hadis/E41CDB061CDAD322/Data/183#گزارش زخم فشاری/40268671_82ae6db6-8890-4490-a80f-7bcfa841cbcd_0.tif',
#  '/media/hadis/E41CDB061CDAD322/Data/183#گزارش زخم فشاری/40268671_9eb68ed6-80b0-43e2-8ce7-e00de3a4945f_0.tif',
#  '/media/hadis/E41CDB061CDAD322/Data/183#گزارش زخم فشاری/40268671_9eb68ed6-80b0-43e2-8ce7-e00de3a4945f_1.tif',
#  '/media/hadis/E41CDB061CDAD322/Data/183#گزارش زخم فشاری/40268671_ac7fc8cf-2e7d-47ab-84ac-33910ef28b88_0.tif',
#  '/media/hadis/E41CDB061CDAD322/Data/183#گزارش زخم فشاری/40268671_ac7fc8cf-2e7d-47ab-84ac-33910ef28b88_1.tif',
# ...

# %%
for i in imageFiles:
    img = Image.open(i)
    text = pytesseract.image_to_string(img).strip()
    if    text == '':
#         print(True)
        os.remove(i)
        print('deleted')
    else : 
        print(False)
# Out:
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# deleted
# False
# deleted
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# deleted
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# deleted
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# deleted
# False
# False
# False
# False
# deleted
# False
# deleted
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# ...
